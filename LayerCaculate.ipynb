# %%
import sys
import math
import numpy

# %%
f = open("atoms.txt")
lines = f.readlines()
for line in lines:
    print(line,)
# Out:
# {\rtf1\ansi\ansicpg936\cocoartf1561\cocoasubrtf400
#
# {\fonttbl\f0\fnil\fcharset0 Menlo-Regular;\f1\fswiss\fcharset0 Helvetica;}
#
# {\colortbl;\red255\green255\blue255;\red0\green0\blue0;\red0\green0\blue0;}
#
# {\*\expandedcolortbl;;\csgray\c0;\csgray\c0\c0;}
#
# \paperw11900\paperh16840\margl1440\margr1440\vieww16360\viewh8400\viewkind0
#
# \deftab593
#
# \pard\tx593\pardeftab593\pardirnatural\partightenfactor0
#
#
#
# \f0\fs24 \cf2 \cb3        1    1    1    -0.800000       2.68278342       1.76225000       3.43000000    0    0    0
#
# \f1 \
#
#
#
# \f0        2    1    1    -0.800000       7.04322133       4.27975000       3.43000000    0    0    0
#
# \f1 \
#
#
#
# \f0        3    1    1    -0.800000      11.40365924       1.76225000       3.43000000    0    0    0
#
# \f1 \
#
#
#
# \f0        4    1    1    -0.800000      15.76409715       4.27975000       3.43000000    0    0    0
#
# \f1 \
#
#
#
# ...

# %%
tests = line.split()
print(tests)
# Out:
# ['\\f0', '3600', '1', '2', '1.200000', '20.26988299', '35.24500000', '34.59726667', '0', '0', '0}']

# %%
testx = float(s[1])
print(testx)
# Out:
# 3600.0

# %%
atom = []
for line in lines:
    atom.append(line.split())

# %%
print(atom[8])
len(atom)
# Out:
# ['\\f0\\fs24', '\\cf2', '\\cb3', '1', '1', '1', '-0.800000', '2.68278342', '1.76225000', '3.43000000', '0', '0', '0']
# 10806

# %%
A = []
i = 8
for index in range(3600):
    A.append(atom[i])
    i = i+3
len(A)
# Out:
# 3600

# %%
print(A[0][7])
print(A[1][7])
# Out:
# 2.68278342
# 3.43000000

# %%
del A[0][0]
del A[0][1]
print(A[0][7])
print(A[1][7])
# Out:
# 3.43000000
# 3.43000000

# %%
#atom data read finished,start bond data read.

# %%
with open("data.Layer", "r") as f:
    lines = f.readlines()

in_bonds = False
blank_counter = 0

for line in lines:
    if in_bonds:
        if line == "\n":
            blank_counter += 1
        else:
            print(line.strip())
    else:
        if line == "Bonds\n":
            in_bonds = True
    
    if blank_counter == 2:
        in_bonds = False
# Out:
# 1        0        1      131
# 2        0        1      141
# 3        0        2      241
# 4        0        2      256
# 5        0        2      132
# 6        0        2      292
# 7        0        3       92
# 8        0        3      107
# 9        0        3      133
# 10        0        3      143
# 11        0        4      243
# 12        0        4      258
# 13        0        4      134
# 14        0        4      294
# 15        0        5       94
# 16        0        5      109
# 17        0        5      135
# 18        0        5      145
# 19        0        6       96
# 20        0        6      111
# 21        0        6      121
# 22        0        6      147
# 23        0        7      247
# 24        0        7      262
# 25        0        7      122
# 26        0        7      298
# 27        0        8       98
# 28        0        8      113
# 29        0        8      123
# 30        0        8      149
# 31        0        9      249
# ...

# %%
import codecs
b = codecs.open("bonds.txt", 'r', 'shift_jis')
bonds = b.readlines()
for bond in bonds:
    print(bond,)
# Out:
# {\rtf1\ansi\ansicpg936\cocoartf1561\cocoasubrtf400
#
# {\fonttbl\f0\fnil\fcharset0 Menlo-Regular;\f1\fswiss\fcharset0 Helvetica;}
#
# {\colortbl;\red255\green255\blue255;\red0\green0\blue0;\red255\green255\blue255;}
#
# {\*\expandedcolortbl;;\csgenericrgb\c0\c0\c0;\csgray\c100000;}
#
# \paperw11900\paperh16840\margl1440\margr1440\vieww10800\viewh8400\viewkind0
#
# \deftab543
#
# \pard\tx543\pardeftab543\pardirnatural\partightenfactor0
#
#
#
# \f0\fs22 \cf2 \cb3        1        0        1      131
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        2        0        1      141
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        3        0        2      241
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        4        0        2      256
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        5        0        2      132
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        6        0        2      292
#
# \f1\fs24 \cf0 \
#
#
#
# \f0\fs22 \cf2        7        0        3       92
#
# \f1\fs24 \cf0 \
#
#
#
# ...

# %%
bond = []
for line in bonds:
    bond.append(line.split())

# %%
B = []
j = 8
for index in range(8976):
    B.append(bond[j])
    j = j+3
len(B)
print(B[0])
print(B[1])
print(B[3000])
# Out:
# ['\\cb3', '1', '0', '1', '131']
# ['\\f0\\fs22', '\\cf2', '2', '0', '1', '141']
# ['\\f0\\fs22', '\\cf2', '3001', '0', '1226', '1316']

# %%
print(B[1][4])
print(B[1][5])
pring(A[])
# Out:
# 1
# 141

# %%
# A[num][x=5,y=6,z=7], B[num][A1=4,A2=5]

# %%
result = (numpy.square(float(A[int(B[1][4])-1][5]) - float(A[int(B[1][5])-1][5])) + numpy.square(float(A[int(B[1][4])-1][6]) - float(A[int(B[1][5])-1][6])) + numpy.square(float(A[int(B[1][4])-1][7]) - float(A[int(B[1][5])-1][7])))
math.sqrt(result)
print(math.sqrt(result))
# Out:
# 1.960224455502713

# %%
i = 1
for index in range(8977):
    temp = (numpy.square(float(A[int(B[i][4])-1][5]) - float(A[int(B[i][5])-1][5])) + numpy.square(float(A[int(B[i][4])-1][6]) - float(A[int(B[i][5])-1][6])) + numpy.square(float(A[int(B[i][4])-1][7]) - float(A[int(B[i][5])-1][7])))
    if math.sqrt(temp) < (2.0):
        print(5)
    elif math.sqrt(temp)> (2.5) and math.sqrt(temp) < (3.0):
        print(4)
    elif math.sqrt(temp) > (2.0) and math.sqrt(temp) < (2.5):
        print(3)
    else:
        print("error")
    print(i)
    i = i + 1
# Out:
# 5
# 1
# 3
# 2
# 3
# 3
# 5
# 4
# 5
# 5
# 3
# 6
# 3
# 7
# 5
# 8
# 5
# 9
# 3
# 10
# 3
# 11
# 5
# 12
# 5
# 13
# 3
# 14
# 3
# 15
# 5
# 16
# 5
# 17
# 3
# 18
# 3
# 19
# 5
# 20
# 5
# 21
# 3
# 22
# 3
# 23
# 5
# 24
# 5
# 25
# 3
# 26
# 3
# 27
# 5
# 28
# 5
# 29
# 3
# 30
# 3
# 31
# 5
# 32
# 5
# 33
# 3
# 34
# 3
# 35
# 5
# 36
# 3
# 37
# 3
# 38
# 5
# 39
# 5
# 40
# 3
# 41
# 3
# 42
# 5
# 43
# 5
# 44
# 3
# 45
# 3
# 46
# 5
# 47
# 5
# 48
# 3
# 49
# 3
# 50
# 5
# 51
# 5
# 52
# 3
# 53
# 3
# 54
# 5
# 55
# 5
# 56
# 3
# 57
# 3
# 58
# 5
# 59
# 5
# 60
# 3
# 61
# 3
# 62
# 5
# 63
# 5
# 64
# 3
# 65
# 3
# 66
# 5
# 67
# 5
# 68
# 3
# 69
# 3
# 70
# 5
# 71
# 5
# 72
# 3
# 73
# 3
# 74
# 5
# 75
# 3
# 76
# 3
# 77
# 5
# 78
# 5
# 79
# 3
# 80
# 3
# 81
# 5
# 82
# 5
# 83
# 3
# 84
# 3
# 85
# 5
# 86
# 5
# 87
# 3
# 88
# 3
# 89
# 5
# 90
# 5
# 91
# 3
# 92
# 3
# 93
# 5
# 94
# 5
# 95
# 3
# 96
# 3
# 97
# 5
# 98
# 3
# 99
# 3
# 100
# 5
# 101
# 5
# 102
# 3
# 103
# 3
# 104
# 5
# 105
# 5
# 106
# 3
# 107
# 3
# 108
# 5
# 109
# 5
# 110
# 3
# ...

# %%
print(A[2550])
print(A[0])
print(B[8397])
print(B[8975])
# Out:
# ['\\f0', '2551', '1', '1', '-0.800000', '2.68278342', '6.79725000', '30.87000000', '0', '0', '0']
# ['\\cf2', '1', '1', '1', '-0.800000', '2.68278342', '1.76225000', '3.43000000', '0', '0', '0']
# ['\\f0\\fs22', '\\cf2', '8398', '0', '51', '2526']
# ['\\f0\\fs22', '\\cf2', '8976', '0', '3475', '2550}']

# %%
result = (numpy.square(float(A[int(B[8974][4])-1][5]) - float(A[int(B[8974][5])-1][5])) + numpy.square(float(A[int(B[8974][4])-1][6]) - float(A[int(B[8974][5])-1][6])) + numpy.square(float(A[int(B[8974][4])-1][7]) - float(A[int(B[8974][5])-1][7])))
print(math.sqrt(result))
print(B[8974])
print(A[int(B[8974][4])-1])
print(A[2549])
# Out:
# 39.56612111262651
# ['\\f0\\fs22', '\\cf2', '8975', '0', '3459', '2550']
# ['\\f0', '3459', '1', '1', '-0.800000', '18.67105575', '39.52475000', '35.44333333', '0', '0', '0']
# ['\\f0', '2550', '1', '2', '1.200000', '20.26988299', '-0.00000000', '34.59726667', '0', '0', '0']
